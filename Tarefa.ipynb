# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.cnnbrasil.com.br/feed/"
response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
soup = BeautifulSoup(response.text, "xml")

headlines = []
for item in soup.find_all("item")[:10]:
    titulo = item.find("title").get_text()
    link = item.find("link").get_text()
    headlines.append({"titulo": titulo, "link": link})

for h in headlines:
    print(f"{h['titulo']}")
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Cell In[6], line 3
#       1 url = "https://www.cnnbrasil.com.br/feed/"
#       2 response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
# ----> 3 soup = BeautifulSoup(response.text, "xml")
#       4
#       5 headlines = []
#       6 for item in soup.find_all("item")[:10]:
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/bs4/__init__.py:366, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     364     possible_builder_class = builder_registry.lookup(*features)
#     365     if possible_builder_class is None:
# --> 366         raise FeatureNotFound(
#     367             "Couldn't find a tree builder with the features you "
#     368             "requested: %s. Do you need to install a parser library?"
#     369             % ",".join(features)
#     370         )
#     371     builder_class = possible_builder_class
#     373 # At this point either we have a TreeBuilder instance in
#     374 # builder, or we have a builder_class that we can instantiate
#     375 # with the remaining **kwargs.
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: xml. Do you need to install a parser library?

# %%
import sqlite3

conn = sqlite3.connect("news.db")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS headlines (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    title TEXT
)
""")

# %%
import sqlite3

conn = sqlite3.connect("news.db")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS headlines (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    title TEXT
)
""")

conn.commit()

# %%
for h in headlines:
    cursor.execute("INSERT INTO headlines (title) VALUES (?)", (h,))

conn.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for h in headlines:
#       2     cursor.execute("INSERT INTO headlines (title) VALUES (?)", (h,))
#       3
#       4 conn.commit()
#
# NameError: name 'headlines' is not defined

# %%
cursor.execute("SELECT * FROM headlines")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cursor.execute("SELECT * FROM headlines")
#       2 rows = cursor.fetchall()
#       3
#       4 for row in rows:
#
# NameError: name 'cursor' is not defined
